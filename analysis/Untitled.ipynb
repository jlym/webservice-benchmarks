# %%
import numpy as np
import pandas as pd
import sqlite3
from datetime import datetime

conn = sqlite3.connect("data.sqlite3")
df = pd.read_sql_query("select * from requests;", conn)

# %%
start_time = df["start_time"][0][:26]
datetime.strptime(start_time, "%Y-%m-%d %H:%M:%S.%f")
# Out:
# datetime.datetime(2019, 8, 19, 21, 45, 28, 475824)

# %%
df.assign(start = pd.to_datetime(df.start_time))
# Out:
#                                         id  worker_id  \
# 0     03fddf0a-1cac-423a-ae28-4cf7e742cb36          2
# 1     655bb52f-800b-4273-86c9-3403fc5c9262          0
# 2     edafad15-bcea-4dea-9f02-c7b9438ae71c          6
# 3     9effe4df-b558-4109-838b-c50c7e9cb11d          9
# 4     ab2c1b7d-919d-4d54-a21a-ee4fd2b6c601          7
# 5     a2bf7bf2-5371-4237-9dfe-7ad1670e7b3c          5
# 6     73b65371-4464-4e16-8cb4-844aed8a8f55          1
# 7     35e83254-900e-4354-a3cf-4cd0dd12e52e          3
# 8     f03ec3c8-99c1-47dd-8ef0-24518d839f69          4
# 9     e965cc4a-741d-45db-b3a6-31ef6007503c          8
# 10    e2fe6e2f-184e-4ab9-9ac5-0a18b94dd243          0
# 11    7a0565d3-8e3a-40ca-854c-06ba96fa189e          2
# 12    dffff18b-594a-45d4-a467-2e62a05bbb70          6
# 13    1d905670-78ab-47ec-b3d0-df21b602634e          9
# 14    13cf7bc5-efdc-4830-a7e9-0ecc380021e4          5
# 15    4411d232-8bc6-496b-b3ed-3399ed6004d4          7
# ...

# %%
df["start"] = df.apply(lambda row: datetime.strptime(row["start_time"][:26], "%Y-%m-%d %H:%M:%S.%f"), axis=1)
df["end"] = df.apply(lambda row: datetime.strptime(row["end_time"][:26], "%Y-%m-%d %H:%M:%S.%f"), axis=1)

def c
df.assign(start = )

# %%
min(df.start)
# Out:
# Timestamp('2019-08-19 21:45:28.475643')
